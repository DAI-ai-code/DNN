# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %%
###-----------------
### Import Libraries
###-----------------
import os
import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns

from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %%
###-----------------
### Global Variables
###-----------------
# inpDir = os.path.join('..', '..', 'input')
# outDir = '../output'
# modelDir = '../models'
# subDir = 'fashion_mnist'
# altName = 'A04_fashion_vanila'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results
tf.random.set_seed(RANDOM_STATE)

# parameters for Matplotlib
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 5),
          'axes.labelsize': 'large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'large',
          'ytick.labelsize':'large'
         }

CMAP = 'brg' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
altName = 'vanilla'

###-----------------
### Hyper Parameters
###-----------------


EPOCHS = 100 # number of epochs
ALPHA = 0.001 # learning rate
BATCH_SIZE = 16 # mini batch size (number of rows)
TRAIN_SIZE = int(18 * BATCH_SIZE)
TEST_SIZE = 0.2
WEIGHT_DECAY = 0.001
PATIENCE = 20
LR_FACTOR = 0.1
LR_PATIENCE = 5
MIN_LR = 1e-6

# %% [markdown]
# ## Load Fashion MNIST dataset

# %% [markdown]
# This guide uses the [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset which contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 by 28 pixels), as seen here:
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST samples</a> (by Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Fashion MNIST is intended as a drop-in replacement for the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset—often used as the "Hello, World" of machine learning programs for computer vision. The MNIST dataset contains images of handwritten digits (0, 1, 2, etc.) in a format identical to that of the articles of clothing you'll use here.
#
# This guide uses Fashion MNIST for variety, and because it's a slightly more challenging problem than regular MNIST. Both datasets are relatively small and are used to verify that an algorithm works as expected. They're good starting points to test and debug code.
#
# Here, 60,000 images are used to train the network and 10,000 images to evaluate how accurately the network learned to classify images. You can access the Fashion MNIST directly from TensorFlow. Import and [load the Fashion MNIST data](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/fashion_mnist/load_data) directly from TensorFlow:

# %%
train_filename = '../input/fashion_mnist/fashion-mnist_train.csv'
test_filename = '../input/fashion_mnist/fashion-mnist_test.csv'

train_df = pd.read_csv(train_filename, header = 0)
test_df = pd.read_csv(test_filename, header = 0)

train_df.shape, test_df.shape
# Out:
# ((60000, 785), (10000, 785))

# %% [markdown]
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>
#
# Each image is mapped to a single label. Since the *class names* are not included with the dataset, store them here to use later when plotting the images:

# %%
# labels
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
              'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# mapping labels to numeric labels
class_names = {0: 'T-shirt/top',1:'Trouser',2:'Pullover',3:'Dress',4:'Coat',
               5:'Sandal', 6: 'Shirt',7: 'Sneaker', 8:'Bag', 9: 'Ankle boot'}

# %%
def fn_plot_label(tr_df, ts_df):
    plt.figure()
    plt.subplot(1,2,1)
    ax = tr_df['label'].value_counts().plot(kind='bar', title='Train', color='DarkBlue', alpha=0.7)
    plt.subplot(1,2,2)
    ax = ts_df['label'].value_counts().plot(kind='bar', title='Test', color='Orange', alpha=0.7)

# %%
plot_df = train_df.sample(n=BATCH_SIZE)
fig = plt.figure()
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

i=0
for _, row in plot_df.iterrows():
    i = i + 1
    image = row.values[1:].reshape(28,28)
    ax = fig.add_subplot(BATCH_SIZE//8, 8, (i), xticks=[], yticks=[])
    ax.imshow(image, cmap=plt.cm.binary, interpolation='nearest')
    ax.text(2,4, str(row.iloc[0]), color='b', fontsize=14)
    ax.text(10,25, class_names[row.iloc[0]], color='r', fontsize=10)
plt.show()

# %%
fn_plot_label(train_df, test_df)

# %% [markdown]
# Balanced data

# %%
def split_feature_label(row):
    feature = tf.reshape(row[1:], [28, 28, 1])
    label = row[0]
    return feature, label

# %%
tmp_ds = tf.data.Dataset.from_tensor_slices(train_df)
train_ds = tmp_ds.map(split_feature_label)
train_ds = train_ds.batch(batch_size=BATCH_SIZE)
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

tmp_ds = tf.data.Dataset.from_tensor_slices(test_df)
test_ds = tmp_ds.map(split_feature_label)
test_ds = test_ds.batch(batch_size=BATCH_SIZE)
test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# fig = plt.figure()
# fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# i=0
# for images, labels in train_ds.take(1):
#     for i in range(BATCH_SIZE):
#         ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[])
#         ax.grid(False)
#         ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary, interpolation='nearest')
#         ax.text(2,4, str(labels[i].numpy()), color='b', fontsize=14)
#         ax.text(10,25, class_names[labels[i].numpy()], color='r', fontsize=10)
# plt.show()

# %%
# fig = plt.figure()
# fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# i=0
# for images, labels in test_ds.take(1):
#     for i in range(BATCH_SIZE):
#         ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[])
#         ax.grid(False)
#         ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary, interpolation='nearest')
#         ax.text(2,4, str(labels[i].numpy()), color='b', fontsize=14)
#         ax.text(10,25, class_names[labels[i].numpy()], color='r', fontsize=10)
# plt.show()

# %% [markdown]
# Rescaling

# %%
# norm_layer = tf.keras.layers.Rescaling(1.0/255)

# print(f'Pre norm - MinMax: {images[0].numpy().min()}, {images[0].numpy().max()}')

# norm_ds = train_ds.map(lambda x, y: (norm_layer(x), y))
# images, labels = next(iter(norm_ds))
# print(f'Post norm - MinMax: {images[0].numpy().min()}, {images[0].numpy().max()}')

# %% [markdown]
# ### conv in action

# %%
input_shape = (1, 6, 6, 1) # batch, 6,6 image, 1 channel
X = tf.random.normal(input_shape)
sns.heatmap(X.numpy()[0, :, :, 0], annot=True, fmt='.2f', cbar=False, cmap='Blues');

# %%
y = tf.keras.layers.Conv2D(1, 3, kernel_initializer=tf.constant_initializer(1.0), use_bias=False, activation='relu')(X)

y.shape
# Out:
# TensorShape([1, 4, 4, 1])

# %%
sns.heatmap(y.numpy()[0, :, :, 0], annot=True, fmt='.2f', cbar=False, cmap='Blues');

# %%
max_pool_2d = tf.keras.layers.MaxPool2D()(y)
max_pool_2d.shape
# Out:
# TensorShape([1, 2, 2, 1])

# %%
sns.heatmap(max_pool_2d.numpy()[0, :, :, 0], annot=True, fmt='.2f', cbar=False, cmap='Blues');

# %%
# checking for missing values
train_df.isna().sum().sum(), test_df.isna().sum().sum()
# Out:
# (np.int64(0), np.int64(0))

# %% [markdown]
# # YHA SE NEW H

# %%
input_shape = (28, 28, 1)

regularizer = tf.keras.regularizers.L2(l2=0.001)

model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=input_shape))
model.add(tf.keras.layers.Rescaling(1.0/255))

# set 1
model.add(tf.keras.layers.Conv2D(32, (3,3), padding='same', 
                                kernel_regularizer=regularizer,
                                activation='relu')) # 28, 28, 32
model.add(tf.keras.layers.MaxPool2D()) # 14, 14, 32

# set 2
model.add(tf.keras.layers.Conv2D(64, (3,3), 
                                kernel_regularizer=regularizer,
                                activation='relu')) # 12, 12, 64
model.add(tf.keras.layers.MaxPool2D()) # 6, 6, 64

# set 3
model.add(tf.keras.layers.Conv2D(128, (3,3),
                                kernel_regularizer=regularizer,
                                activation='relu')) # 4, 4, 128

model.add(tf.keras.layers.Flatten())
# head
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10))

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) # loss function
optimizer = tf.keras.optimizers.AdamW(learning_rate=ALPHA)   # optimizer
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy']) # model compilation

# %%
# CALLBACKS


# Stops training early if validation loss stops improving to prevent overfitting
es_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE,
    verbose=1,
    restore_best_weights=True  # Fixed typo: restore_best_weight -> restore_best_weights
)


# Reduces learning rate when validation loss plateaus to help convergence
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(  # Fixed variable name conflict
    monitor='val_loss',
    factor=LR_FACTOR,
    patience=LR_PATIENCE,
    verbose=1,
    mode='auto',
    min_lr=MIN_LR,
)

# %%
history = model.fit(train_ds, validation_data=test_ds, 
                    epochs=EPOCHS, callbacks=[reduce_lr_callback, es_callback])
# Out:
# Epoch 1/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - accuracy: 0.8410 - loss: 0.5113 - val_accuracy: 0.8807 - val_loss: 0.3931 - learning_rate: 0.0010
# Epoch 2/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.8858 - loss: 0.3737 - val_accuracy: 0.8965 - val_loss: 0.3483 - learning_rate: 0.0010
# Epoch 3/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.8989 - loss: 0.3345 - val_accuracy: 0.8988 - val_loss: 0.3357 - learning_rate: 0.0010
# Epoch 4/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9061 - loss: 0.3115 - val_accuracy: 0.8994 - val_loss: 0.3304 - learning_rate: 0.0010
# Epoch 5/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9120 - loss: 0.2940 - val_accuracy: 0.9035 - val_loss: 0.3247 - learning_rate: 0.0010
# Epoch 6/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9168 - loss: 0.2816 - val_accuracy: 0.9017 - val_loss: 0.3297 - learning_rate: 0.0010
# Epoch 7/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9217 - loss: 0.2711 - val_accuracy: 0.9075 - val_loss: 0.3108 - learning_rate: 0.0010
# Epoch 8/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9255 - loss: 0.2615 - val_accuracy: 0.9025 - val_loss: 0.3282 - learning_rate: 0.0010
# Epoch 9/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9288 - loss: 0.2540 - val_accuracy: 0.9066 - val_loss: 0.3229 - learning_rate: 0.0010
# Epoch 10/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9302 - loss: 0.2484 - val_accuracy: 0.9076 - val_loss: 0.3311 - learning_rate: 0.0010
# Epoch 11/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9337 - loss: 0.2415 - val_accuracy: 0.9102 - val_loss: 0.3133 - learning_rate: 0.0010
# Epoch 12/100
# 3746/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9356 - loss: 0.2358
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9355 - loss: 0.2361 - val_accuracy: 0.9104 - val_loss: 0.3231 - learning_rate: 0.0010
# Epoch 13/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9481 - loss: 0.2008 - val_accuracy: 0.9238 - val_loss: 0.2735 - learning_rate: 1.0000e-04
# Epoch 14/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9542 - loss: 0.1828 - val_accuracy: 0.9249 - val_loss: 0.2679 - learning_rate: 1.0000e-04
# Epoch 15/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9571 - loss: 0.1740 - val_accuracy: 0.9244 - val_loss: 0.2637 - learning_rate: 1.0000e-04
# Epoch 16/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9590 - loss: 0.1677 - val_accuracy: 0.9248 - val_loss: 0.2616 - learning_rate: 1.0000e-04
# Epoch 17/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9608 - loss: 0.1625 - val_accuracy: 0.9245 - val_loss: 0.2608 - learning_rate: 1.0000e-04
# Epoch 18/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9625 - loss: 0.1581 - val_accuracy: 0.9244 - val_loss: 0.2612 - learning_rate: 1.0000e-04
# Epoch 19/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9639 - loss: 0.1542 - val_accuracy: 0.9248 - val_loss: 0.2612 - learning_rate: 1.0000e-04
# Epoch 20/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9651 - loss: 0.1508 - val_accuracy: 0.9232 - val_loss: 0.2618 - learning_rate: 1.0000e-04
# Epoch 21/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9663 - loss: 0.1476 - val_accuracy: 0.9241 - val_loss: 0.2627 - learning_rate: 1.0000e-04
# Epoch 22/100
# 3746/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9661 - loss: 0.1460
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9674 - loss: 0.1445 - val_accuracy: 0.9244 - val_loss: 0.2627 - learning_rate: 1.0000e-04
# Epoch 23/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9667 - loss: 0.1429 - val_accuracy: 0.9299 - val_loss: 0.2543 - learning_rate: 1.0000e-05
# Epoch 24/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9686 - loss: 0.1399 - val_accuracy: 0.9300 - val_loss: 0.2544 - learning_rate: 1.0000e-05
# Epoch 25/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9689 - loss: 0.1390 - val_accuracy: 0.9302 - val_loss: 0.2544 - learning_rate: 1.0000e-05
# Epoch 26/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9692 - loss: 0.1383 - val_accuracy: 0.9305 - val_loss: 0.2543 - learning_rate: 1.0000e-05
# Epoch 27/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9694 - loss: 0.1377 - val_accuracy: 0.9310 - val_loss: 0.2543 - learning_rate: 1.0000e-05
# Epoch 28/100
# 3746/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9678 - loss: 0.1394
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9697 - loss: 0.1372 - val_accuracy: 0.9309 - val_loss: 0.2543 - learning_rate: 1.0000e-05
# Epoch 29/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9697 - loss: 0.1367 - val_accuracy: 0.9307 - val_loss: 0.2542 - learning_rate: 1.0000e-06
# Epoch 30/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9700 - loss: 0.1364 - val_accuracy: 0.9309 - val_loss: 0.2542 - learning_rate: 1.0000e-06
# Epoch 31/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9700 - loss: 0.1362 - val_accuracy: 0.9309 - val_loss: 0.2542 - learning_rate: 1.0000e-06
# Epoch 32/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9702 - loss: 0.1361 - val_accuracy: 0.9305 - val_loss: 0.2543 - learning_rate: 1.0000e-06
# Epoch 33/100
# 3746/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9684 - loss: 0.1386
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9702 - loss: 0.1360 - val_accuracy: 0.9307 - val_loss: 0.2543 - learning_rate: 1.0000e-06
# Epoch 34/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9702 - loss: 0.1360 - val_accuracy: 0.9306 - val_loss: 0.2543 - learning_rate: 1.0000e-06
# Epoch 35/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9701 - loss: 0.1359 - val_accuracy: 0.9306 - val_loss: 0.2543 - learning_rate: 1.0000e-06
# Epoch 36/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9702 - loss: 0.1358 - val_accuracy: 0.9306 - val_loss: 0.2543 - learning_rate: 1.0000e-06
# Epoch 37/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9702 - loss: 0.1357 - val_accuracy: 0.9305 - val_loss: 0.2543 - learning_rate: 1.0000e-06
# Epoch 38/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9702 - loss: 0.1357 - val_accuracy: 0.9306 - val_loss: 0.2543 - learning_rate: 1.0000e-06
# Epoch 39/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9703 - loss: 0.1356 - val_accuracy: 0.9304 - val_loss: 0.2543 - learning_rate: 1.0000e-06
# Epoch 40/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9703 - loss: 0.1356 - val_accuracy: 0.9303 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 41/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 38s 10ms/step - accuracy: 0.9703 - loss: 0.1355 - val_accuracy: 0.9303 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 42/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9704 - loss: 0.1355 - val_accuracy: 0.9302 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 43/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9704 - loss: 0.1354 - val_accuracy: 0.9303 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 44/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9704 - loss: 0.1353 - val_accuracy: 0.9303 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 45/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 38s 10ms/step - accuracy: 0.9704 - loss: 0.1353 - val_accuracy: 0.9303 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 46/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 38s 10ms/step - accuracy: 0.9705 - loss: 0.1352 - val_accuracy: 0.9304 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 47/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - accuracy: 0.9705 - loss: 0.1352 - val_accuracy: 0.9304 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 48/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - accuracy: 0.9705 - loss: 0.1351 - val_accuracy: 0.9304 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 49/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - accuracy: 0.9705 - loss: 0.1351 - val_accuracy: 0.9304 - val_loss: 0.2544 - learning_rate: 1.0000e-06
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 29.

# %%
hist_df = pd.DataFrame(history.history)
fn_plot_tf_hist(hist_df)

# %% [markdown]
# ### Train pred

# %%
y_train = tf.concat([y for x, y in train_ds], axis=0).numpy()
print(y_train.shape)
# Out:
# (60000,)

# %%
yhat = model.predict(train_ds)
y_pred = yhat.argmax(axis=1)
print(f'Accuracy: {accuracy_score(y_train, y_pred):.5f}')
print(classification_report(y_train, y_pred))
# Out:
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step
# Accuracy: 0.92673
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      6000
#            1       1.00      0.98      0.99      6000
#            2       0.91      0.87      0.89      6000
#            3       0.90      0.95      0.93      6000
#            4       0.88      0.85      0.87      6000
#            5       1.00      0.98      0.99      6000
#            6       0.75      0.85      0.80      6000
#            7       0.97      0.97      0.97      6000
#            8       0.99      0.99      0.99      6000
#            9       0.96      0.99      0.97      6000
#
#     accuracy                           0.93     60000
#    macro avg       0.93      0.93      0.93     60000
# weighted avg       0.93      0.93      0.93     60000

# %%
fn_plot_confusion_matrix(y_train, y_pred, class_names)

# %% [markdown]
# ### Test pred

# %%
y_test = tf.concat([y for x, y in test_ds], axis=0).numpy()
print(y_test.shape)
# Out:
# (10000,)

# %%
yhat = model.predict(test_ds)
y_pred = yhat.argmax(axis=1)
print(f'Accuracy: {accuracy_score(y_test, y_pred):.5f}')
print(classification_report(y_test, y_pred))
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# Accuracy: 0.91400
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86      1000
#            1       1.00      0.98      0.99      1000
#            2       0.90      0.85      0.87      1000
#            3       0.89      0.95      0.92      1000
#            4       0.88      0.85      0.87      1000
#            5       0.99      0.96      0.98      1000
#            6       0.73      0.81      0.77      1000
#            7       0.95      0.96      0.95      1000
#            8       0.98      0.98      0.98      1000
#            9       0.95      0.98      0.96      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.92      0.91      0.91     10000
# weighted avg       0.92      0.91      0.91     10000

# %%
fn_plot_confusion_matrix(y_test, y_pred, class_names)

# %% [markdown]
# model(images)

# %%
fig = plt.figure(figsize=(15, 8))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

i=0
for images, labels in train_ds.take(1):
    yhat = model(images).numpy()
    y_pred = yhat.argmax(axis=1)

    for i in range(BATCH_SIZE):
        ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[])
        ax.grid(False)
        color = 'cyan'
        if y_pred[i] != labels[i]:
            color='red'
        props = dict(boxstyle='round', facecolor=color, alpha=0.5)
        ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary)

        ax.text(0.1, 0.90, class_names[y_pred[i]] , bbox=props,
                verticalalignment='top',
                transform=ax.transAxes, fontsize=14)
        
        ax.set_title(class_names[labels[i].numpy()], fontsize=14)
plt.tight_layout()
plt.show()
