# %% [markdown]
# # Deep Neural Networks
# ## Session 25c
#
# ##  [Yolo V3](https://pjreddie.com/darknet/yolo/)
#
# <img src='../../prasami_images/prasami_color_tutorials_small.png' style = 'width:400px;' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>
#
#
# - Based on https://github.com/experiencor/keras-yolo3
# - Additional Dataset https://cocodataset.org/#home

# %%
### Import Libraries

import tensorflow as tf

import os

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

from matplotlib.patches import Rectangle


# import struct

from yolov3_util import decode_netout, WeightReader, correct_yolo_boxes, do_nms, make_yolov3_model

# from tensorflow.keras.layers import Conv2D

# from tensorflow.keras.layers import Input
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.layers import LeakyReLU
# from tensorflow.keras.layers import ZeroPadding2D
# from tensorflow.keras.layers import UpSampling2D
# from tensorflow.keras.layers import add, concatenate
# from tensorflow.keras.models import Model

physical_devices = tf.config.list_physical_devices('GPU') 

# tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Some basic parameters

inpDir = '../input' # location where input data is stored
outDir = '../input/output' # location to store outputs
mdlDir = 'D:\\DAI Aug-25\\dnnnn\\yolo\\yolo' # location to store outputs
imgDir = 'yolo_images'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
EPOCHS = 100 # number of cycles to run

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'medium',
          'figure.figsize'  : (15,15),
          'axes.labelsize'  : 'large',
          'axes.titlesize'  :'large',
          'xtick.labelsize' :'medium',
          'ytick.labelsize' :'medium'
         }

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Overview
# The most salient feature of v3 is that it makes detections at three different scales.
# ### [Bounding box](http://christopher5106.github.io/object/detectors/2017/08/10/bounding-box-object-detectors-understanding-yolo.html)
# YOLO v3 predicts boxes at 3 different scales. For the same image of 416 x 416, the number of predicted boxes are 10,647.
#
# - For the 13x13 feature map, there are 13 * 13 * 3 = 507 anchor boxes.  (416/32)
# - For the 26x26 feature map, there are 26 * 26 * 3 = 2,028 anchor boxes. (416/16)
# - For the 52x52 feature map, there are 52 * 52 * 3 = 8,112 anchor boxes. (416/8)
#
# Total 10647 anchor boxes

# %%
416/32
# Out:
# 13.0

# %%
# define the labels
'''labels = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck",
          "boat", "traffic light", "fire hydrant", "stop sign", "parking meter", "bench",
          "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe",
          "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard",
          "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard",
          "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana",
          "apple", "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake",
          "chair", "sofa", "pottedplant", "bed", "diningtable", "toilet", "tvmonitor", "laptop", "mouse",
          "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink", "refrigerator",
          "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"]
'''
labels = ["person", "bicycle", "car", "motorbike", "pottedplant"]

# define the expected input shape for the model
input_w, input_h = 416, 416

# Anchor Size
anchors = [[116,90, 156,198, 373,326], [30,61, 62,45, 59,119], [10,13, 16,30, 33,23]]

# define the probability threshold for detected objects
class_threshold = 0.1 #0.7 # 0.3

nonmaxsup_threshold= 0.2 #0.45 #0.2

# %% [markdown]
# ## Note on Anchor Box:
# **Anchor box dimensions:** Each sub-list contains the dimensions (width, height) of the anchor boxes. The dimensions are specified in pairs. For example, the first sub-list [116,90, 156,198, 373,326] contains three anchor boxes with dimensions (116, 90), (156, 198), and (373, 326).
#
# ### Breaking down the anchors parameter:
# **First set of anchors ([116,90, 156,198, 373,326]):**
# These anchor boxes are used on the coarsest feature map (usually downsampled by a factor of 32).
#
# **Second set of anchors ([30,61, 62,45, 59,119]):**
# These anchor boxes are used on the medium-resolution feature map (usually downsampled by a factor of 16).
#
# **Third set of anchors ([10,13, 16,30, 33,23]):**
# These anchor boxes are used on the finest feature map (usually downsampled by a factor of 8).
#
# The purpose of having multiple sets of anchors at different scales is to allow YOLOv3 to detect objects of varying sizes effectively. The coarser scales with larger anchor boxes are better suited for detecting large objects, while the finer scales with smaller anchor boxes are better suited for detecting small objects. This multi-scale detection approach enhances the model's ability to accurately predict bounding boxes for objects of different sizes within the same image.

# %%
model = make_yolov3_model() # define the model

weight_reader = WeightReader(os.path.join(mdlDir, 'yolov3.weights')) # load the model weights

weight_reader.load_weights(model) # set the model weights into the model


model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy']) # Compile the model

# save the model to file
model.save(os.path.join(mdlDir, 'yolo3_model.keras'))
# Out:
# d:\DAI Aug-25\softwares\conda_env\dnn\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# loading weights of convolution #0
# loading weights of convolution #1
# loading weights of convolution #2
# loading weights of convolution #3
# no convolution #4
# loading weights of convolution #5
# loading weights of convolution #6
# loading weights of convolution #7
# no convolution #8
# loading weights of convolution #9
# loading weights of convolution #10
# no convolution #11
# loading weights of convolution #12
# loading weights of convolution #13
# loading weights of convolution #14
# no convolution #15
# loading weights of convolution #16
# loading weights of convolution #17
# no convolution #18
# loading weights of convolution #19
# loading weights of convolution #20
# no convolution #21
# loading weights of convolution #22
# loading weights of convolution #23
# no convolution #24
# loading weights of convolution #25
# loading weights of convolution #26
# no convolution #27
# loading weights of convolution #28
# loading weights of convolution #29
# no convolution #30
# loading weights of convolution #31
# loading weights of convolution #32
# no convolution #33
# loading weights of convolution #34
# loading weights of convolution #35
# no convolution #36
# loading weights of convolution #37
# loading weights of convolution #38
# loading weights of convolution #39
# no convolution #40
# loading weights of convolution #41
# loading weights of convolution #42
# no convolution #43
# loading weights of convolution #44
# loading weights of convolution #45
# no convolution #46
# loading weights of convolution #47
# loading weights of convolution #48
# no convolution #49
# loading weights of convolution #50
# loading weights of convolution #51
# no convolution #52
# loading weights of convolution #53
# loading weights of convolution #54
# no convolution #55
# loading weights of convolution #56
# loading weights of convolution #57
# no convolution #58
# loading weights of convolution #59
# loading weights of convolution #60
# no convolution #61
# loading weights of convolution #62
# loading weights of convolution #63
# loading weights of convolution #64
# no convolution #65
# loading weights of convolution #66
# loading weights of convolution #67
# no convolution #68
# loading weights of convolution #69
# loading weights of convolution #70
# no convolution #71
# loading weights of convolution #72
# loading weights of convolution #73
# no convolution #74
# loading weights of convolution #75
# loading weights of convolution #76
# loading weights of convolution #77
# loading weights of convolution #78
# loading weights of convolution #79
# loading weights of convolution #80
# loading weights of convolution #81
# no convolution #82
# no convolution #83
# loading weights of convolution #84
# no convolution #85
# no convolution #86
# loading weights of convolution #87
# loading weights of convolution #88
# loading weights of convolution #89
# loading weights of convolution #90
# loading weights of convolution #91
# loading weights of convolution #92
# loading weights of convolution #93
# no convolution #94
# no convolution #95
# loading weights of convolution #96
# no convolution #97
# no convolution #98
# loading weights of convolution #99
# loading weights of convolution #100
# loading weights of convolution #101
# loading weights of convolution #102
# loading weights of convolution #103
# loading weights of convolution #104
# loading weights of convolution #105

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_0 (Conv2D)     │ (None, None,      │        864 │ input_layer_2[0]… │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_0             │ (None, None,      │        128 │ conv_0[0][0]      │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_0 (LeakyReLU) │ (None, None,      │          0 │ bnorm_0[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_10   │ (None, None,      │          0 │ leaky_0[0][0]     │
# │ (ZeroPadding2D)     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, None,      │     18,432 │ zero_padding2d_1… │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_1             │ (None, None,      │        256 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_1 (LeakyReLU) │ (None, None,      │          0 │ bnorm_1[0][0]     │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_2 (Conv2D)     │ (None, None,      │      2,048 │ leaky_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_2             │ (None, None,      │        128 │ conv_2[0][0]      │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_2 (LeakyReLU) │ (None, None,      │          0 │ bnorm_2[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_3 (Conv2D)     │ (None, None,      │     18,432 │ leaky_2[0][0]     │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_3             │ (None, None,      │        256 │ conv_3[0][0]      │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_3 (LeakyReLU) │ (None, None,      │          0 │ bnorm_3[0][0]     │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_46 (Add)        │ (None, None,      │          0 │ leaky_1[0][0],    │
# │                     │ None, 64)         │            │ leaky_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_11   │ (None, None,      │          0 │ add_46[0][0]      │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_5 (Conv2D)     │ (None, None,      │     73,728 │ zero_padding2d_1… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_5             │ (None, None,      │        512 │ conv_5[0][0]      │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_5 (LeakyReLU) │ (None, None,      │          0 │ bnorm_5[0][0]     │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_6 (Conv2D)     │ (None, None,      │      8,192 │ leaky_5[0][0]     │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_6             │ (None, None,      │        256 │ conv_6[0][0]      │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_6 (LeakyReLU) │ (None, None,      │          0 │ bnorm_6[0][0]     │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_7 (Conv2D)     │ (None, None,      │     73,728 │ leaky_6[0][0]     │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_7             │ (None, None,      │        512 │ conv_7[0][0]      │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_7 (LeakyReLU) │ (None, None,      │          0 │ bnorm_7[0][0]     │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_47 (Add)        │ (None, None,      │          0 │ leaky_5[0][0],    │
# │                     │ None, 128)        │            │ leaky_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_9 (Conv2D)     │ (None, None,      │      8,192 │ add_47[0][0]      │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_9             │ (None, None,      │        256 │ conv_9[0][0]      │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_9 (LeakyReLU) │ (None, None,      │          0 │ bnorm_9[0][0]     │
# │                     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_10 (Conv2D)    │ (None, None,      │     73,728 │ leaky_9[0][0]     │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_10            │ (None, None,      │        512 │ conv_10[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_10            │ (None, None,      │          0 │ bnorm_10[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_48 (Add)        │ (None, None,      │          0 │ add_47[0][0],     │
# │                     │ None, 128)        │            │ leaky_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_12   │ (None, None,      │          0 │ add_48[0][0]      │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_12 (Conv2D)    │ (None, None,      │    294,912 │ zero_padding2d_1… │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_12            │ (None, None,      │      1,024 │ conv_12[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_12            │ (None, None,      │          0 │ bnorm_12[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_13 (Conv2D)    │ (None, None,      │     32,768 │ leaky_12[0][0]    │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_13            │ (None, None,      │        512 │ conv_13[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_13            │ (None, None,      │          0 │ bnorm_13[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_14 (Conv2D)    │ (None, None,      │    294,912 │ leaky_13[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_14            │ (None, None,      │      1,024 │ conv_14[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_14            │ (None, None,      │          0 │ bnorm_14[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_49 (Add)        │ (None, None,      │          0 │ leaky_12[0][0],   │
# │                     │ None, 256)        │            │ leaky_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_16 (Conv2D)    │ (None, None,      │     32,768 │ add_49[0][0]      │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_16            │ (None, None,      │        512 │ conv_16[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_16            │ (None, None,      │          0 │ bnorm_16[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_17 (Conv2D)    │ (None, None,      │    294,912 │ leaky_16[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_17            │ (None, None,      │      1,024 │ conv_17[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_17            │ (None, None,      │          0 │ bnorm_17[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_50 (Add)        │ (None, None,      │          0 │ add_49[0][0],     │
# │                     │ None, 256)        │            │ leaky_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_19 (Conv2D)    │ (None, None,      │     32,768 │ add_50[0][0]      │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_19            │ (None, None,      │        512 │ conv_19[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_19            │ (None, None,      │          0 │ bnorm_19[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_20 (Conv2D)    │ (None, None,      │    294,912 │ leaky_19[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_20            │ (None, None,      │      1,024 │ conv_20[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_20            │ (None, None,      │          0 │ bnorm_20[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_51 (Add)        │ (None, None,      │          0 │ add_50[0][0],     │
# │                     │ None, 256)        │            │ leaky_20[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_22 (Conv2D)    │ (None, None,      │     32,768 │ add_51[0][0]      │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_22            │ (None, None,      │        512 │ conv_22[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_22            │ (None, None,      │          0 │ bnorm_22[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_23 (Conv2D)    │ (None, None,      │    294,912 │ leaky_22[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_23            │ (None, None,      │      1,024 │ conv_23[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_23            │ (None, None,      │          0 │ bnorm_23[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_52 (Add)        │ (None, None,      │          0 │ add_51[0][0],     │
# │                     │ None, 256)        │            │ leaky_23[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_25 (Conv2D)    │ (None, None,      │     32,768 │ add_52[0][0]      │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_25            │ (None, None,      │        512 │ conv_25[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_25            │ (None, None,      │          0 │ bnorm_25[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_26 (Conv2D)    │ (None, None,      │    294,912 │ leaky_25[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_26            │ (None, None,      │      1,024 │ conv_26[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_26            │ (None, None,      │          0 │ bnorm_26[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_53 (Add)        │ (None, None,      │          0 │ add_52[0][0],     │
# │                     │ None, 256)        │            │ leaky_26[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_28 (Conv2D)    │ (None, None,      │     32,768 │ add_53[0][0]      │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_28            │ (None, None,      │        512 │ conv_28[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_28            │ (None, None,      │          0 │ bnorm_28[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_29 (Conv2D)    │ (None, None,      │    294,912 │ leaky_28[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_29            │ (None, None,      │      1,024 │ conv_29[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_29            │ (None, None,      │          0 │ bnorm_29[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_54 (Add)        │ (None, None,      │          0 │ add_53[0][0],     │
# │                     │ None, 256)        │            │ leaky_29[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_31 (Conv2D)    │ (None, None,      │     32,768 │ add_54[0][0]      │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_31            │ (None, None,      │        512 │ conv_31[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_31            │ (None, None,      │          0 │ bnorm_31[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_32 (Conv2D)    │ (None, None,      │    294,912 │ leaky_31[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_32            │ (None, None,      │      1,024 │ conv_32[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_32            │ (None, None,      │          0 │ bnorm_32[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_55 (Add)        │ (None, None,      │          0 │ add_54[0][0],     │
# │                     │ None, 256)        │            │ leaky_32[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_34 (Conv2D)    │ (None, None,      │     32,768 │ add_55[0][0]      │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_34            │ (None, None,      │        512 │ conv_34[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_34            │ (None, None,      │          0 │ bnorm_34[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_35 (Conv2D)    │ (None, None,      │    294,912 │ leaky_34[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_35            │ (None, None,      │      1,024 │ conv_35[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_35            │ (None, None,      │          0 │ bnorm_35[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_56 (Add)        │ (None, None,      │          0 │ add_55[0][0],     │
# │                     │ None, 256)        │            │ leaky_35[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_13   │ (None, None,      │          0 │ add_56[0][0]      │
# │ (ZeroPadding2D)     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_37 (Conv2D)    │ (None, None,      │  1,179,648 │ zero_padding2d_1… │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_37            │ (None, None,      │      2,048 │ conv_37[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_37            │ (None, None,      │          0 │ bnorm_37[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_38 (Conv2D)    │ (None, None,      │    131,072 │ leaky_37[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_38            │ (None, None,      │      1,024 │ conv_38[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_38            │ (None, None,      │          0 │ bnorm_38[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_39 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_38[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_39            │ (None, None,      │      2,048 │ conv_39[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_39            │ (None, None,      │          0 │ bnorm_39[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_57 (Add)        │ (None, None,      │          0 │ leaky_37[0][0],   │
# │                     │ None, 512)        │            │ leaky_39[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_41 (Conv2D)    │ (None, None,      │    131,072 │ add_57[0][0]      │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_41            │ (None, None,      │      1,024 │ conv_41[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_41            │ (None, None,      │          0 │ bnorm_41[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_42 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_41[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_42            │ (None, None,      │      2,048 │ conv_42[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_42            │ (None, None,      │          0 │ bnorm_42[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_58 (Add)        │ (None, None,      │          0 │ add_57[0][0],     │
# │                     │ None, 512)        │            │ leaky_42[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_44 (Conv2D)    │ (None, None,      │    131,072 │ add_58[0][0]      │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_44            │ (None, None,      │      1,024 │ conv_44[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_44            │ (None, None,      │          0 │ bnorm_44[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_45 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_44[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_45            │ (None, None,      │      2,048 │ conv_45[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_45            │ (None, None,      │          0 │ bnorm_45[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_59 (Add)        │ (None, None,      │          0 │ add_58[0][0],     │
# │                     │ None, 512)        │            │ leaky_45[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_47 (Conv2D)    │ (None, None,      │    131,072 │ add_59[0][0]      │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_47            │ (None, None,      │      1,024 │ conv_47[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_47            │ (None, None,      │          0 │ bnorm_47[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_48 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_47[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_48            │ (None, None,      │      2,048 │ conv_48[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_48            │ (None, None,      │          0 │ bnorm_48[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_60 (Add)        │ (None, None,      │          0 │ add_59[0][0],     │
# │                     │ None, 512)        │            │ leaky_48[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_50 (Conv2D)    │ (None, None,      │    131,072 │ add_60[0][0]      │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_50            │ (None, None,      │      1,024 │ conv_50[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_50            │ (None, None,      │          0 │ bnorm_50[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_51 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_50[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_51            │ (None, None,      │      2,048 │ conv_51[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_51            │ (None, None,      │          0 │ bnorm_51[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_61 (Add)        │ (None, None,      │          0 │ add_60[0][0],     │
# │                     │ None, 512)        │            │ leaky_51[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_53 (Conv2D)    │ (None, None,      │    131,072 │ add_61[0][0]      │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_53            │ (None, None,      │      1,024 │ conv_53[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_53            │ (None, None,      │          0 │ bnorm_53[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_54 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_53[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_54            │ (None, None,      │      2,048 │ conv_54[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_54            │ (None, None,      │          0 │ bnorm_54[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_62 (Add)        │ (None, None,      │          0 │ add_61[0][0],     │
# │                     │ None, 512)        │            │ leaky_54[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_56 (Conv2D)    │ (None, None,      │    131,072 │ add_62[0][0]      │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_56            │ (None, None,      │      1,024 │ conv_56[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_56            │ (None, None,      │          0 │ bnorm_56[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_57 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_56[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_57            │ (None, None,      │      2,048 │ conv_57[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_57            │ (None, None,      │          0 │ bnorm_57[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_63 (Add)        │ (None, None,      │          0 │ add_62[0][0],     │
# │                     │ None, 512)        │            │ leaky_57[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_59 (Conv2D)    │ (None, None,      │    131,072 │ add_63[0][0]      │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_59            │ (None, None,      │      1,024 │ conv_59[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_59            │ (None, None,      │          0 │ bnorm_59[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_60 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_59[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_60            │ (None, None,      │      2,048 │ conv_60[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_60            │ (None, None,      │          0 │ bnorm_60[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_64 (Add)        │ (None, None,      │          0 │ add_63[0][0],     │
# │                     │ None, 512)        │            │ leaky_60[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_14   │ (None, None,      │          0 │ add_64[0][0]      │
# │ (ZeroPadding2D)     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_62 (Conv2D)    │ (None, None,      │  4,718,592 │ zero_padding2d_1… │
# │                     │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_62            │ (None, None,      │      4,096 │ conv_62[0][0]     │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_62            │ (None, None,      │          0 │ bnorm_62[0][0]    │
# │ (LeakyReLU)         │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_63 (Conv2D)    │ (None, None,      │    524,288 │ leaky_62[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_63            │ (None, None,      │      2,048 │ conv_63[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_63            │ (None, None,      │          0 │ bnorm_63[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_64 (Conv2D)    │ (None, None,      │  4,718,592 │ leaky_63[0][0]    │
# │                     │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_64            │ (None, None,      │      4,096 │ conv_64[0][0]     │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_64            │ (None, None,      │          0 │ bnorm_64[0][0]    │
# │ (LeakyReLU)         │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_65 (Add)        │ (None, None,      │          0 │ leaky_62[0][0],   │
# │                     │ None, 1024)       │            │ leaky_64[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_66 (Conv2D)    │ (None, None,      │    524,288 │ add_65[0][0]      │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_66            │ (None, None,      │      2,048 │ conv_66[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_66            │ (None, None,      │          0 │ bnorm_66[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_67 (Conv2D)    │ (None, None,      │  4,718,592 │ leaky_66[0][0]    │
# │                     │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_67            │ (None, None,      │      4,096 │ conv_67[0][0]     │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_67            │ (None, None,      │          0 │ bnorm_67[0][0]    │
# │ (LeakyReLU)         │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_66 (Add)        │ (None, None,      │          0 │ add_65[0][0],     │
# │                     │ None, 1024)       │            │ leaky_67[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_69 (Conv2D)    │ (None, None,      │    524,288 │ add_66[0][0]      │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_69            │ (None, None,      │      2,048 │ conv_69[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_69            │ (None, None,      │          0 │ bnorm_69[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_70 (Conv2D)    │ (None, None,      │  4,718,592 │ leaky_69[0][0]    │
# │                     │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_70            │ (None, None,      │      4,096 │ conv_70[0][0]     │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_70            │ (None, None,      │          0 │ bnorm_70[0][0]    │
# │ (LeakyReLU)         │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_67 (Add)        │ (None, None,      │          0 │ add_66[0][0],     │
# │                     │ None, 1024)       │            │ leaky_70[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_72 (Conv2D)    │ (None, None,      │    524,288 │ add_67[0][0]      │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_72            │ (None, None,      │      2,048 │ conv_72[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_72            │ (None, None,      │          0 │ bnorm_72[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_73 (Conv2D)    │ (None, None,      │  4,718,592 │ leaky_72[0][0]    │
# │                     │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_73            │ (None, None,      │      4,096 │ conv_73[0][0]     │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_73            │ (None, None,      │          0 │ bnorm_73[0][0]    │
# │ (LeakyReLU)         │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_68 (Add)        │ (None, None,      │          0 │ add_67[0][0],     │
# │                     │ None, 1024)       │            │ leaky_73[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_75 (Conv2D)    │ (None, None,      │    524,288 │ add_68[0][0]      │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_75            │ (None, None,      │      2,048 │ conv_75[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_75            │ (None, None,      │          0 │ bnorm_75[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_76 (Conv2D)    │ (None, None,      │  4,718,592 │ leaky_75[0][0]    │
# │                     │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_76            │ (None, None,      │      4,096 │ conv_76[0][0]     │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_76            │ (None, None,      │          0 │ bnorm_76[0][0]    │
# │ (LeakyReLU)         │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_77 (Conv2D)    │ (None, None,      │    524,288 │ leaky_76[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_77            │ (None, None,      │      2,048 │ conv_77[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_77            │ (None, None,      │          0 │ bnorm_77[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_78 (Conv2D)    │ (None, None,      │  4,718,592 │ leaky_77[0][0]    │
# │                     │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_78            │ (None, None,      │      4,096 │ conv_78[0][0]     │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_78            │ (None, None,      │          0 │ bnorm_78[0][0]    │
# │ (LeakyReLU)         │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_79 (Conv2D)    │ (None, None,      │    524,288 │ leaky_78[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_79            │ (None, None,      │      2,048 │ conv_79[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_79            │ (None, None,      │          0 │ bnorm_79[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_84 (Conv2D)    │ (None, None,      │    131,072 │ leaky_79[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_84            │ (None, None,      │      1,024 │ conv_84[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_84            │ (None, None,      │          0 │ bnorm_84[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, None,      │          0 │ leaky_84[0][0]    │
# │ (UpSampling2D)      │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, None,      │          0 │ up_sampling2d_4[… │
# │ (Concatenate)       │ None, 768)        │            │ add_64[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_87 (Conv2D)    │ (None, None,      │    196,608 │ concatenate_4[0]… │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_87            │ (None, None,      │      1,024 │ conv_87[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_87            │ (None, None,      │          0 │ bnorm_87[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_88 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_87[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_88            │ (None, None,      │      2,048 │ conv_88[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_88            │ (None, None,      │          0 │ bnorm_88[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_89 (Conv2D)    │ (None, None,      │    131,072 │ leaky_88[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_89            │ (None, None,      │      1,024 │ conv_89[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_89            │ (None, None,      │          0 │ bnorm_89[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_90 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_89[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_90            │ (None, None,      │      2,048 │ conv_90[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_90            │ (None, None,      │          0 │ bnorm_90[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_91 (Conv2D)    │ (None, None,      │    131,072 │ leaky_90[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_91            │ (None, None,      │      1,024 │ conv_91[0][0]     │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_91            │ (None, None,      │          0 │ bnorm_91[0][0]    │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_96 (Conv2D)    │ (None, None,      │     32,768 │ leaky_91[0][0]    │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_96            │ (None, None,      │        512 │ conv_96[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_96            │ (None, None,      │          0 │ bnorm_96[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, None,      │          0 │ leaky_96[0][0]    │
# │ (UpSampling2D)      │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, None,      │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ None, 384)        │            │ add_56[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_99 (Conv2D)    │ (None, None,      │     49,152 │ concatenate_5[0]… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_99            │ (None, None,      │        512 │ conv_99[0][0]     │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_99            │ (None, None,      │          0 │ bnorm_99[0][0]    │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_100 (Conv2D)   │ (None, None,      │    294,912 │ leaky_99[0][0]    │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_100           │ (None, None,      │      1,024 │ conv_100[0][0]    │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_100           │ (None, None,      │          0 │ bnorm_100[0][0]   │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_101 (Conv2D)   │ (None, None,      │     32,768 │ leaky_100[0][0]   │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_101           │ (None, None,      │        512 │ conv_101[0][0]    │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_101           │ (None, None,      │          0 │ bnorm_101[0][0]   │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_102 (Conv2D)   │ (None, None,      │    294,912 │ leaky_101[0][0]   │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_102           │ (None, None,      │      1,024 │ conv_102[0][0]    │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_102           │ (None, None,      │          0 │ bnorm_102[0][0]   │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_103 (Conv2D)   │ (None, None,      │     32,768 │ leaky_102[0][0]   │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_103           │ (None, None,      │        512 │ conv_103[0][0]    │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_103           │ (None, None,      │          0 │ bnorm_103[0][0]   │
# │ (LeakyReLU)         │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_80 (Conv2D)    │ (None, None,      │  4,718,592 │ leaky_79[0][0]    │
# │                     │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_92 (Conv2D)    │ (None, None,      │  1,179,648 │ leaky_91[0][0]    │
# │                     │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_104 (Conv2D)   │ (None, None,      │    294,912 │ leaky_103[0][0]   │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_80            │ (None, None,      │      4,096 │ conv_80[0][0]     │
# │ (BatchNormalizatio… │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_92            │ (None, None,      │      2,048 │ conv_92[0][0]     │
# │ (BatchNormalizatio… │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bnorm_104           │ (None, None,      │      1,024 │ conv_104[0][0]    │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_80            │ (None, None,      │          0 │ bnorm_80[0][0]    │
# │ (LeakyReLU)         │ None, 1024)       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_92            │ (None, None,      │          0 │ bnorm_92[0][0]    │
# │ (LeakyReLU)         │ None, 512)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_104           │ (None, None,      │          0 │ bnorm_104[0][0]   │
# │ (LeakyReLU)         │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_81 (Conv2D)    │ (None, None,      │    261,375 │ leaky_80[0][0]    │
# │                     │ None, 255)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_93 (Conv2D)    │ (None, None,      │    130,815 │ leaky_92[0][0]    │
# │                     │ None, 255)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_105 (Conv2D)   │ (None, None,      │     65,535 │ leaky_104[0][0]   │
# │                     │ None, 255)        │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 62,001,757 (236.52 MB)
#  Trainable params: 61,949,149 (236.32 MB)
#  Non-trainable params: 52,608 (205.50 KB)

# %%
# load yolov3 model
# model = tf.keras.models.load_model(os.path.join(mdlDir, 'yolo3_model.h5'))

# tf.keras.utils.plot_model(
#     model,
#     to_file=os.path.join(mdlDir, 'yolov3.png'),
#     show_shapes=True,
#     show_dtype=True)

# %%
# load and prepare an image
def load_image_pixels(filename, shape):
    
    # load the image to get its shape
    image = tf.keras.preprocessing.image.load_img(filename)
    width, height = image.size
    
    # load the image with the required size (Should not we be better off loading once????)
    #image = tf.keras.preprocessing.image.load_img(filename, target_size=shape) # as per original paper
    image = tf.keras.preprocessing.image.smart_resize(image,shape)

    # convert to a 3D Numpy array. 
    image = tf.keras.preprocessing.image.img_to_array(image)
    
    # scale values to between 0 and 1
    image = image.astype('float32')
    image /= 255.0
    
    #print ('before expand', image.shape, 'max pixel value', image.max())
    
    # add a dimension so that we have one sample
    image = tf.expand_dims(image, 0)
    #print ('after expand', image.shape)
    
    return image, width, height

# %%
# get all of the results above a threshold
def get_boxes(boxes, labels, thresh):
    v_boxes, v_labels, v_scores = list(), list(), list()

    # iterate all boxes
    for box in boxes:
        
        # iteratare all possible labels
        for i in range(len(labels)):
            
            # check if the threshold for this label is high enough to be listed
            if box.classes[i] > thresh:
                v_boxes.append(box)
                v_labels.append(labels[i])
                v_scores.append(box.classes[i]*100) # don't break, many labels may trigger for one box
                
    return v_boxes, v_labels, v_scores

# %%
# draw all results
def draw_boxes(filename, v_boxes, v_labels, v_scores):
    
    # load the image
    data = plt.imread(filename)
    
    # plot the image
    plt.imshow(data)
    
    # get the context for drawing boxes
    ax = plt.gca()

    # plot each box
    for i in range(len(v_boxes)):

        box = v_boxes[i]
        
        # get coordinates
        y1, x1, y2, x2 = box.ymin, box.xmin, box.ymax, box.xmax
        
        # calculate width and height of the box
        width, height = x2 - x1, y2 - y1
        
        # create the shape
        rect = Rectangle((x1, y1), width, height, fill=False, color='white')
        
        # draw the box
        ax.add_patch(rect)
        
        # draw text and score in top left corner
        label = "{:s} ({:.0f}%)".format(v_labels[i], v_scores[i])
        
        plt.text(x1, y1, label, color='white')
        
        img_name = filename.split('/')[-1]      
        plt.savefig(os.path.join(outDir, img_name))
    
    # show the plot
    plt.show()

# %%
test_data_dir = os.path.join(inpDir, imgDir)
    
imgList = [f for f in os.listdir(test_data_dir) if os.path.isfile(os.path.join(test_data_dir, f))]

# %%
imgList
# Out:
# ['IMG_1292.JPG',
#  'IMG_1293_mod.png',
#  'IMG_1293_mod.xcf',
#  'IMG_1295.JPG',
#  'IMG_1296.JPG',
#  'street.jpg']

# %%
# define our new photo
photo_filename = os.path.join(test_data_dir, imgList[0])


# load and prepare image
image, image_w, image_h = load_image_pixels(photo_filename, (input_w, input_h))

# make prediction
y_pred = model.predict(image)

# summarize the shape of the list of arrays
print([a.shape for a in y_pred])

boxes = list()
for i in range(len(y_pred)):
    # decode the output of the network
    boxes += decode_netout(y_pred[i][0], anchors[i], class_threshold, nonmaxsup_threshold, input_h, input_w)

# correct the sizes of the bounding boxes for the shape of the image
correct_yolo_boxes(boxes, image_h, image_w, input_h, input_w)

# suppress non-maximal boxes
do_nms(boxes, nonmaxsup_threshold)

# get the details of the detected objects
v_boxes, v_labels, v_scores = get_boxes(boxes, labels, class_threshold)

# What did you find in the picture
for i in range(len(v_boxes)):
    print(v_labels[i], v_scores[i])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# [(1, 13, 13, 255), (1, 26, 26, 255), (1, 52, 52, 255)]
# motorbike 85.72114
# person 99.67786
# motorbike 99.85712
# motorbike 56.380646
# motorbike 24.042004
# motorbike 95.65251
# motorbike 11.03668
# motorbike 76.601494
# motorbike 32.208786
# person 17.780472

# %%
draw_boxes(photo_filename, v_boxes, v_labels, v_scores)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 draw_boxes(photo_filename, v_boxes, v_labels, v_scores)
#
# Cell In[31], line 36, in draw_boxes(filename, v_boxes, v_labels, v_scores)
#      33     plt.text(x1, y1, label, color='white')
#      35     img_name = filename.split('/')[-1]
# ---> 36     plt.savefig(os.path.join(outDir, img_name))
#      38 # show the plot
#      39 plt.show()
#
# File d:\DAI Aug-25\softwares\conda_env\dnn\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File d:\DAI Aug-25\softwares\conda_env\dnn\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File d:\DAI Aug-25\softwares\conda_env\dnn\Lib\site-packages\matplotlib\backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File d:\DAI Aug-25\softwares\conda_env\dnn\Lib\site-packages\matplotlib\backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File d:\DAI Aug-25\softwares\conda_env\dnn\Lib\site-packages\matplotlib\backends\backend_agg.py:498, in FigureCanvasAgg.print_jpg(self, filename_or_obj, metadata, pil_kwargs)
#     493 def print_jpg(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     494     # savefig() has already applied savefig.facecolor; we now set it to
#     495     # white to make imsave() blend semi-transparent figures against an
#     496     # assumed white background.
#     497     with mpl.rc_context({"savefig.facecolor": "white"}):
# --> 498         self._print_pil(filename_or_obj, "jpeg", pil_kwargs, metadata)
#
# File d:\DAI Aug-25\softwares\conda_env\dnn\Lib\site-packages\matplotlib\backends\backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File d:\DAI Aug-25\softwares\conda_env\dnn\Lib\site-packages\matplotlib\image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File d:\DAI Aug-25\softwares\conda_env\dnn\Lib\site-packages\PIL\Image.py:2591, in Image.save(self, fp, format, **params)
#    2589         fp = builtins.open(filename, "r+b")
#    2590     else:
# -> 2591         fp = builtins.open(filename, "w+b")
#    2592 else:
#    2593     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/output\\input\\yolo_images\\IMG_1292.JPG'

# %%
len(y_pred)
# Out:
# 3

# %%
y_pred[0][0].shape, anchors[0]
# Out:
# ((13, 13, 255), [116, 90, 156, 198, 373, 326])

# %%
grid_h, grid_w = y_pred[0][0].shape[:2]
grid_h, grid_w
# Out:
# (13, 13)

# %%
y_pred[0][0][..., :2]
# Out:
# array([[[0.42410854, 0.57156533],
#         [0.6073285 , 0.6065222 ],
#         [0.6016198 , 0.56978595],
#         [0.5106258 , 0.61290205],
#         [0.5475636 , 0.57046795],
#         [0.6574413 , 0.54549885],
#         [0.37296474, 0.6114771 ],
#         [0.31447425, 0.6092223 ],
#         [0.37547255, 0.62056255],
#         [0.4841557 , 0.6218236 ],
#         [0.38181075, 0.6207073 ],
#         [0.32442772, 0.60972416],
#         [0.47406256, 0.4640999 ]],
#
#        [[0.41341457, 0.6421845 ],
#         [0.573922  , 0.667242  ],
#         [0.6108511 , 0.57871884],
#         [0.52418226, 0.5434287 ],
#         [0.4989372 , 0.51100266],
#         [0.6030478 , 0.42081827],
#         [0.30702332, 0.3892118 ],
#         [0.32204866, 0.32751074],
#         [0.49600095, 0.33617312],
#         [0.61174035, 0.46549433],
#         [0.40929815, 0.53331184],
#         [0.3782605 , 0.60285753],
#         [0.42901784, 0.5515589 ]],
#
#        [[0.40408558, 0.45569754],
#         [0.6299027 , 0.45232695],
#         [0.55938154, 0.48501685],
#         [0.50510436, 0.3983389 ],
#         [0.43167916, 0.36704698],
#         [0.5786256 , 0.3429525 ],
#         [0.38823316, 0.3446739 ],
#         [0.33371413, 0.45284677],
#         [0.52457166, 0.5224903 ],
#         [0.6299329 , 0.46430346],
#         [0.41665488, 0.40873978],
#         [0.39246172, 0.4672558 ],
#         [0.5119604 , 0.5290565 ]],
#
#        [[0.52315795, 0.6262229 ],
#         [0.64170396, 0.75202304],
#         [0.45802006, 0.7892566 ],
#         [0.4992652 , 0.76440346],
#         [0.4937675 , 0.8084185 ],
#         [0.7795556 , 0.92937165],
#         [0.3311216 , 0.9089609 ],
#         [0.44557458, 0.76603425],
#         [0.53139466, 0.7436965 ],
#         [0.58612174, 0.7408172 ],
#         [0.41091782, 0.801092  ],
#         [0.34285823, 0.73649085],
#         [0.5181612 , 0.5719792 ]],
#
#        [[0.63089657, 0.4270519 ],
#         [0.71348107, 0.48636842],
#         [0.44242686, 0.67819685],
#         [0.46953064, 0.5717473 ],
#         [0.51170367, 0.5084398 ],
#         [0.8427429 , 0.43172094],
#         [0.1824793 , 0.44030082],
#         [0.4553703 , 0.56804115],
#         [0.5408367 , 0.59565294],
#         [0.47189456, 0.46515912],
#         [0.553067  , 0.52215016],
#         [0.26993707, 0.5564861 ],
#         [0.48932967, 0.49295098]],
#
#        [[0.5927007 , 0.32485086],
#         [0.76160884, 0.3157372 ],
#         [0.3947913 , 0.2835572 ],
#         [0.3950207 , 0.3333174 ],
#         [0.47077113, 0.3699621 ],
#         [0.69114256, 0.21425052],
#         [0.49795613, 0.28411323],
#         [0.6493965 , 0.86940295],
#         [0.15275109, 0.72795194],
#         [0.32293823, 0.40342748],
#         [0.60868305, 0.26631892],
#         [0.35177144, 0.39288902],
#         [0.5652177 , 0.5027234 ]],
#
#        [[0.53597724, 0.433923  ],
#         [0.714187  , 0.41769397],
#         [0.38376322, 0.34534305],
#         [0.43438083, 0.4302205 ],
#         [0.44557828, 0.4211469 ],
#         [0.5456666 , 0.43747005],
#         [0.6772009 , 0.3430081 ],
#         [0.689674  , 0.137524  ],
#         [0.09843951, 0.25832126],
#         [0.29414582, 0.431107  ],
#         [0.64671934, 0.5879793 ],
#         [0.45855957, 0.68925935],
#         [0.45610112, 0.5175228 ]],
#
#        [[0.5510171 , 0.59417576],
#         [0.65108675, 0.64057696],
#         [0.3974732 , 0.5328527 ],
#         [0.44357282, 0.47111693],
#         [0.426725  , 0.4114429 ],
#         [0.49634796, 0.41994482],
#         [0.4117512 , 0.3784059 ],
#         [0.5719407 , 0.211114  ],
#         [0.34653375, 0.25258538],
#         [0.36267892, 0.38161498],
#         [0.68416685, 0.35670128],
#         [0.47714207, 0.24622817],
#         [0.4274996 , 0.40441918]],
#
#        [[0.5219329 , 0.3122243 ],
#         [0.64495236, 0.29034567],
#         [0.4227605 , 0.32292387],
#         [0.4367097 , 0.4018025 ],
#         [0.4533195 , 0.457819  ],
#         [0.5070966 , 0.51063395],
#         [0.42364836, 0.5309091 ],
#         [0.41887912, 0.47194308],
#         [0.40735364, 0.5280929 ],
#         [0.44764966, 0.6387168 ],
#         [0.55640095, 0.6248748 ],
#         [0.37439692, 0.46899742],
#         [0.575714  , 0.48299256]],
#
#        [[0.4349344 , 0.517694  ],
#         [0.6541076 , 0.4830423 ],
#         [0.49833846, 0.5063136 ],
#         [0.53581065, 0.6458934 ],
#         [0.49881744, 0.6385076 ],
#         [0.55915266, 0.6419444 ],
#         [0.48744798, 0.6594738 ],
#         [0.31308758, 0.55864465],
#         [0.4799268 , 0.4347596 ],
#         [0.48489243, 0.45522016],
#         [0.51375175, 0.39144212],
#         [0.330635  , 0.39364883],
#         [0.6050069 , 0.45743093]],
#
#        [[0.47722566, 0.57854676],
#         [0.7210699 , 0.5341205 ],
#         [0.63080806, 0.4984847 ],
#         [0.534659  , 0.49029747],
#         [0.4583514 , 0.5213565 ],
#         [0.5639101 , 0.61365443],
#         [0.50868124, 0.64686805],
#         [0.22519405, 0.53005975],
#         [0.48128968, 0.46109566],
#         [0.5479564 , 0.5352316 ],
#         [0.46493417, 0.6113277 ],
#         [0.31561086, 0.52579385],
#         [0.5831178 , 0.5312389 ]],
#
#        [[0.41488975, 0.55957913],
#         [0.61834145, 0.5067569 ],
#         [0.5070495 , 0.396629  ],
#         [0.51154035, 0.27811003],
#         [0.5365779 , 0.32830128],
#         [0.700997  , 0.4227627 ],
#         [0.5104492 , 0.43842947],
#         [0.17135288, 0.5400587 ],
#         [0.41091737, 0.5537821 ],
#         [0.63172245, 0.5109055 ],
#         [0.4622769 , 0.5271009 ],
#         [0.2893966 , 0.6222247 ],
#         [0.5230267 , 0.5889664 ]],
#
#        [[0.41283742, 0.315917  ],
#         [0.70361567, 0.22037964],
#         [0.52118915, 0.3669694 ],
#         [0.51148003, 0.44390807],
#         [0.50210446, 0.46360993],
#         [0.6295667 , 0.43771654],
#         [0.53478664, 0.33389723],
#         [0.25741437, 0.3563683 ],
#         [0.38329226, 0.40311256],
#         [0.5453705 , 0.37002236],
#         [0.49472228, 0.27871767],
#         [0.3435427 , 0.21674964],
#         [0.48629403, 0.37788865]]], dtype=float32)

# %%
objectness = y_pred[0][0][..., :4]
objectness
# Out:
# array([[[ 4.24108535e-01,  5.71565330e-01,  4.68333960e-01,
#          -4.78411138e-01],
#         [ 6.07328475e-01,  6.06522202e-01,  3.50236446e-01,
#          -5.78382075e-01],
#         [ 6.01619780e-01,  5.69785953e-01,  6.25446856e-01,
#          -8.01299810e-01],
#         [ 5.10625780e-01,  6.12902045e-01,  7.01124012e-01,
#          -8.91371369e-01],
#         [ 5.47563612e-01,  5.70467949e-01,  9.84329343e-01,
#          -9.71068263e-01],
#         [ 6.57441318e-01,  5.45498848e-01,  1.23834538e+00,
#          -1.03377366e+00],
#         [ 3.72964740e-01,  6.11477077e-01,  1.22353005e+00,
#          -9.66761351e-01],
#         [ 3.14474255e-01,  6.09222293e-01,  1.19178867e+00,
#          -1.03276896e+00],
#         [ 3.75472546e-01,  6.20562553e-01,  9.84576941e-01,
#          -9.83346939e-01],
#         [ 4.84155715e-01,  6.21823609e-01,  8.83605003e-01,
#          -9.60801840e-01],
#         [ 3.81810755e-01,  6.20707273e-01,  7.11779833e-01,
#          -8.80782962e-01],
#         [ 3.24427724e-01,  6.09724164e-01,  5.67635179e-01,
#          -7.37732410e-01],
#         [ 4.74062562e-01,  4.64099914e-01,  6.86404467e-01,
#          -5.99995315e-01]],
#
#        [[ 4.13414568e-01,  6.42184496e-01, -2.28382081e-01,
#          -1.90335646e-01],
#         [ 5.73921978e-01,  6.67241991e-01, -1.80316776e-01,
#          -3.44624221e-02],
#         [ 6.10851109e-01,  5.78718841e-01,  2.97288746e-01,
#          -1.90038383e-01],
#         [ 5.24182260e-01,  5.43428719e-01,  4.51727092e-01,
#          -2.61598289e-01],
#         [ 4.98937190e-01,  5.11002660e-01,  7.12053418e-01,
#          -3.81964445e-01],
#         [ 6.03047788e-01,  4.20818269e-01,  1.10318768e+00,
#          -5.37538886e-01],
#         [ 3.07023317e-01,  3.89211804e-01,  1.20991099e+00,
#          -5.48130155e-01],
#         [ 3.22048664e-01,  3.27510744e-01,  1.12895048e+00,
#          -5.85747421e-01],
#         [ 4.96000946e-01,  3.36173117e-01,  7.81650603e-01,
#          -4.72972870e-01],
#         [ 6.11740351e-01,  4.65494335e-01,  5.32724261e-01,
#          -3.91529322e-01],
#         [ 4.09298152e-01,  5.33311844e-01,  5.21691084e-01,
#          -3.13499331e-01],
#         [ 3.78260493e-01,  6.02857530e-01,  9.39261690e-02,
#          -1.41467765e-01],
#         [ 4.29017842e-01,  5.51558912e-01,  1.56899899e-01,
#          -3.19133699e-01]],
#
#        [[ 4.04085577e-01,  4.55697536e-01, -2.26392657e-01,
#          -5.08343577e-02],
#         [ 6.29902720e-01,  4.52326953e-01, -2.06346959e-01,
#           1.50229871e-01],
#         [ 5.59381545e-01,  4.85016853e-01,  1.62188798e-01,
#          -1.50384456e-01],
#         [ 5.05104363e-01,  3.98338914e-01,  3.36140305e-01,
#          -2.91466892e-01],
#         [ 4.31679159e-01,  3.67046982e-01,  5.13062000e-01,
#          -4.11741495e-01],
#         [ 5.78625619e-01,  3.42952490e-01,  8.70283961e-01,
#          -5.71050227e-01],
#         [ 3.88233155e-01,  3.44673902e-01,  1.03676295e+00,
#          -5.92718244e-01],
#         [ 3.33714128e-01,  4.52846766e-01,  1.00847793e+00,
#          -6.11326575e-01],
#         [ 5.24571657e-01,  5.22490323e-01,  6.32436156e-01,
#          -4.53752398e-01],
#         [ 6.29932880e-01,  4.64303464e-01,  3.33326399e-01,
#          -3.17701280e-01],
#         [ 4.16654885e-01,  4.08739775e-01,  2.73697406e-01,
#          -1.55274913e-01],
#         [ 3.92461717e-01,  4.67255801e-01, -9.79918018e-02,
#           1.70955792e-01],
#         [ 5.11960387e-01,  5.29056489e-01, -7.89253190e-02,
#           5.57040870e-02]],
#
#        [[ 5.23157954e-01,  6.26222908e-01, -1.39179349e-01,
#          -2.44047806e-01],
#         [ 6.41703963e-01,  7.52023041e-01, -1.77627534e-01,
#          -1.23463482e-01],
#         [ 4.58020061e-01,  7.89256573e-01,  1.90327555e-01,
#          -3.45881104e-01],
#         [ 4.99265194e-01,  7.64403462e-01,  3.16189110e-01,
#          -4.03226912e-01],
#         [ 4.93767500e-01,  8.08418512e-01,  4.51181203e-01,
#          -4.31576431e-01],
#         [ 7.79555619e-01,  9.29371655e-01,  1.00580670e-01,
#          -4.41437900e-01],
#         [ 3.31121594e-01,  9.08960879e-01,  2.28044838e-01,
#          -3.81354332e-01],
#         [ 4.45574582e-01,  7.66034245e-01,  9.11631465e-01,
#          -5.27975261e-01],
#         [ 5.31394660e-01,  7.43696511e-01,  6.44402504e-01,
#          -5.51129341e-01],
#         [ 5.86121738e-01,  7.40817189e-01,  3.69187802e-01,
#          -5.45324564e-01],
#         [ 4.10917819e-01,  8.01092029e-01,  2.80249864e-01,
#          -4.13786829e-01],
#         [ 3.42858225e-01,  7.36490846e-01, -6.54274747e-02,
#          -1.83109567e-01],
#         [ 5.18161178e-01,  5.71979225e-01,  1.08253226e-01,
#          -3.17170799e-01]],
#
#        [[ 6.30896568e-01,  4.27051902e-01, -1.93304196e-02,
#          -2.41029218e-01],
#         [ 7.13481069e-01,  4.86368418e-01, -1.52621120e-01,
#          -1.17797509e-01],
#         [ 4.42426860e-01,  6.78196847e-01,  1.72696263e-01,
#          -1.53828070e-01],
#         [ 4.69530642e-01,  5.71747303e-01,  2.62872398e-01,
#          -2.36153349e-01],
#         [ 5.11703670e-01,  5.08439779e-01,  4.18661743e-01,
#          -1.96641251e-01],
#         [ 8.42742920e-01,  4.31720942e-01, -2.05087632e-01,
#          -2.59798050e-01],
#         [ 1.82479307e-01,  4.40300822e-01, -1.50976896e-01,
#          -2.88158715e-01],
#         [ 4.55370307e-01,  5.68041146e-01,  5.09520531e-01,
#          -5.20806730e-01],
#         [ 5.40836692e-01,  5.95652938e-01,  5.14940739e-01,
#          -6.26710653e-01],
#         [ 4.71894562e-01,  4.65159118e-01,  3.70678514e-01,
#          -5.12899697e-01],
#         [ 5.53067029e-01,  5.22150159e-01,  2.45333880e-01,
#          -4.53621089e-01],
#         [ 2.69937068e-01,  5.56486130e-01, -7.31629804e-02,
#          -3.19019377e-01],
#         [ 4.89329666e-01,  4.92950976e-01,  3.74234557e-01,
#          -4.63332891e-01]],
#
#        [[ 5.92700720e-01,  3.24850857e-01,  1.68063998e-01,
#          -2.12565258e-01],
#         [ 7.61608839e-01,  3.15737188e-01, -1.02204941e-01,
#          -5.17435372e-04],
#         [ 3.94791305e-01,  2.83557206e-01,  1.74828485e-01,
#          -4.73906547e-02],
#         [ 3.95020694e-01,  3.33317399e-01,  3.97428423e-01,
#          -1.20649099e-01],
#         [ 4.70771134e-01,  3.69962096e-01,  4.32529360e-01,
#          -1.84553847e-01],
#         [ 6.91142559e-01,  2.14250520e-01,  1.49871886e-01,
#          -1.31886914e-01],
#         [ 4.97956127e-01,  2.84113228e-01, -8.17896426e-03,
#          -7.85391331e-02],
#         [ 6.49396479e-01,  8.69402945e-01,  3.14065397e-01,
#           1.87124625e-01],
#         [ 1.52751088e-01,  7.27951944e-01,  2.45903522e-01,
#           1.06174372e-01],
#         [ 3.22938234e-01,  4.03427482e-01,  3.29814225e-01,
#          -1.43989921e-01],
#         [ 6.08683050e-01,  2.66318917e-01,  2.88665712e-01,
#          -2.41130427e-01],
#         [ 3.51771444e-01,  3.92889023e-01,  1.24780461e-02,
#          -1.10012919e-01],
#         [ 5.65217674e-01,  5.02723396e-01,  4.08658803e-01,
#          -3.10567439e-01]],
#
#        [[ 5.35977244e-01,  4.33923006e-01,  1.48125648e-01,
#          -1.20808914e-01],
#         [ 7.14187026e-01,  4.17693973e-01, -1.32511795e-01,
#           5.11600301e-02],
#         [ 3.83763224e-01,  3.45343053e-01,  2.21965969e-01,
#          -1.27213717e-01],
#         [ 4.34380829e-01,  4.30220515e-01,  4.97501582e-01,
#          -1.66237682e-01],
#         [ 4.45578277e-01,  4.21146899e-01,  5.68126500e-01,
#          -1.80333555e-01],
#         [ 5.45666575e-01,  4.37470049e-01,  6.64721131e-01,
#          -6.03731498e-02],
#         [ 6.77200913e-01,  3.43008101e-01,  3.40265840e-01,
#           7.79896528e-02],
#         [ 6.89674020e-01,  1.37523994e-01,  2.89690971e-01,
#           2.20550492e-01],
#         [ 9.84395146e-02,  2.58321255e-01,  2.93568224e-01,
#           2.07549721e-01],
#         [ 2.94145823e-01,  4.31107014e-01,  1.08203791e-01,
#           1.62575021e-01],
#         [ 6.46719337e-01,  5.87979317e-01,  2.26643175e-01,
#           7.60401189e-02],
#         [ 4.58559573e-01,  6.89259350e-01, -1.18407480e-01,
#           9.49212238e-02],
#         [ 4.56101120e-01,  5.17522812e-01,  2.08250612e-01,
#          -1.38561979e-01]],
#
#        [[ 5.51017106e-01,  5.94175756e-01,  4.63025197e-02,
#          -1.26213163e-01],
#         [ 6.51086748e-01,  6.40576959e-01, -2.04577535e-01,
#           1.35330319e-01],
#         [ 3.97473186e-01,  5.32852709e-01,  1.75558925e-01,
#          -1.34066865e-02],
#         [ 4.43572819e-01,  4.71116930e-01,  4.38659966e-01,
#          -9.35841352e-02],
#         [ 4.26725000e-01,  4.11442906e-01,  5.33952415e-01,
#          -1.55759379e-01],
#         [ 4.96347964e-01,  4.19944823e-01,  8.41557324e-01,
#          -2.35241070e-01],
#         [ 4.11751211e-01,  3.78405899e-01,  7.14537740e-01,
#          -2.65912175e-01],
#         [ 5.71940720e-01,  2.11114004e-01,  2.59421378e-01,
#          -3.10438693e-01],
#         [ 3.46533746e-01,  2.52585381e-01,  2.66569972e-01,
#          -2.73230255e-01],
#         [ 3.62678915e-01,  3.81614983e-01,  3.27174723e-01,
#          -2.48308107e-01],
#         [ 6.84166849e-01,  3.56701285e-01,  2.59486526e-01,
#          -1.47120491e-01],
#         [ 4.77142066e-01,  2.46228173e-01, -1.68681264e-01,
#           2.53794715e-02],
#         [ 4.27499592e-01,  4.04419184e-01,  1.96242496e-01,
#          -1.93130746e-01]],
#
#        [[ 5.21932900e-01,  3.12224299e-01,  7.88438097e-02,
#          -2.08775535e-01],
#         [ 6.44952357e-01,  2.90345669e-01, -2.02895880e-01,
#          -3.05086449e-02],
#         [ 4.22760487e-01,  3.22923869e-01,  2.13117868e-01,
#          -2.24258646e-01],
#         [ 4.36709702e-01,  4.01802510e-01,  3.81101042e-01,
#          -2.84957945e-01],
#         [ 4.53319490e-01,  4.57819015e-01,  4.81126726e-01,
#          -3.38976860e-01],
#         [ 5.07096589e-01,  5.10633945e-01,  7.40131080e-01,
#          -4.23051059e-01],
#         [ 4.23648357e-01,  5.30909121e-01,  9.22807634e-01,
#          -4.05295134e-01],
#         [ 4.18879122e-01,  4.71943080e-01,  5.95169604e-01,
#          -4.02293265e-01],
#         [ 4.07353640e-01,  5.28092921e-01,  5.36647558e-01,
#          -4.77661550e-01],
#         [ 4.47649658e-01,  6.38716817e-01,  5.77992499e-01,
#          -4.95191097e-01],
#         [ 5.56400955e-01,  6.24874771e-01,  3.27555805e-01,
#          -3.83649349e-01],
#         [ 3.74396920e-01,  4.68997419e-01, -7.18230084e-02,
#          -8.02244022e-02],
#         [ 5.75713992e-01,  4.82992560e-01,  2.66665399e-01,
#          -2.33864471e-01]],
#
#        [[ 4.34934407e-01,  5.17693996e-01,  3.25280249e-01,
#          -3.26853335e-01],
#         [ 6.54107571e-01,  4.83042300e-01, -2.41810456e-02,
#          -1.42867684e-01],
#         [ 4.98338461e-01,  5.06313622e-01,  3.35563153e-01,
#          -3.34095001e-01],
#         [ 5.35810649e-01,  6.45893395e-01,  4.63432699e-01,
#          -3.66195440e-01],
#         [ 4.98817444e-01,  6.38507605e-01,  6.00328803e-01,
#          -3.60176563e-01],
#         [ 5.59152663e-01,  6.41944408e-01,  8.42232049e-01,
#          -4.36216116e-01],
#         [ 4.87447977e-01,  6.59473777e-01,  1.17255616e+00,
#          -3.26716065e-01],
#         [ 3.13087583e-01,  5.58644652e-01,  9.53126848e-01,
#          -3.39897096e-01],
#         [ 4.79926795e-01,  4.34759587e-01,  6.59831882e-01,
#          -3.09800565e-01],
#         [ 4.84892428e-01,  4.55220163e-01,  6.20578170e-01,
#          -3.24192405e-01],
#         [ 5.13751745e-01,  3.91442120e-01,  3.28186333e-01,
#          -2.43157580e-01],
#         [ 3.30635011e-01,  3.93648833e-01, -1.90073624e-02,
#          -6.07349351e-02],
#         [ 6.05006874e-01,  4.57430929e-01,  2.43431121e-01,
#          -2.28168800e-01]],
#
#        [[ 4.77225661e-01,  5.78546762e-01,  2.05002010e-01,
#          -2.06007093e-01],
#         [ 7.21069872e-01,  5.34120500e-01, -4.87149432e-02,
#          -1.34413347e-01],
#         [ 6.30808055e-01,  4.98484701e-01,  2.38220870e-01,
#          -2.91572034e-01],
#         [ 5.34659028e-01,  4.90297467e-01,  4.83290464e-01,
#          -2.43315265e-01],
#         [ 4.58351403e-01,  5.21356523e-01,  5.84521830e-01,
#          -1.88490525e-01],
#         [ 5.63910127e-01,  6.13654435e-01,  8.11347544e-01,
#          -2.43307933e-01],
#         [ 5.08681238e-01,  6.46868050e-01,  1.20133662e+00,
#          -2.03574479e-01],
#         [ 2.25194052e-01,  5.30059755e-01,  1.07460093e+00,
#          -3.89837921e-01],
#         [ 4.81289685e-01,  4.61095661e-01,  6.71267986e-01,
#          -4.41096842e-01],
#         [ 5.47956407e-01,  5.35231590e-01,  5.28426409e-01,
#          -3.88510942e-01],
#         [ 4.64934170e-01,  6.11327708e-01,  2.59089679e-01,
#          -2.15679929e-01],
#         [ 3.15610856e-01,  5.25793850e-01, -5.71357682e-02,
#           1.65411383e-02],
#         [ 5.83117783e-01,  5.31238914e-01,  2.18125731e-01,
#          -2.05959305e-01]],
#
#        [[ 4.14889753e-01,  5.59579134e-01, -1.10372253e-01,
#          -6.22189939e-02],
#         [ 6.18341446e-01,  5.06756902e-01, -6.98194429e-02,
#           5.30770384e-02],
#         [ 5.07049501e-01,  3.96629006e-01,  1.84536994e-01,
#          -6.04113638e-02],
#         [ 5.11540353e-01,  2.78110027e-01,  4.51299757e-01,
#          -6.21644557e-02],
#         [ 5.36577880e-01,  3.28301281e-01,  5.26227951e-01,
#          -6.06218725e-02],
#         [ 7.00996995e-01,  4.22762692e-01,  9.01727855e-01,
#          -1.24508321e-01],
#         [ 5.10449171e-01,  4.38429475e-01,  1.18722689e+00,
#          -3.00137699e-02],
#         [ 1.71352878e-01,  5.40058672e-01,  1.12295794e+00,
#          -1.73242554e-01],
#         [ 4.10917372e-01,  5.53782105e-01,  6.73907220e-01,
#          -2.10394636e-01],
#         [ 6.31722450e-01,  5.10905504e-01,  4.37684923e-01,
#          -1.95606828e-01],
#         [ 4.62276906e-01,  5.27100921e-01,  1.98838487e-01,
#          -1.65579155e-01],
#         [ 2.89396614e-01,  6.22224689e-01, -1.10663004e-01,
#          -6.58059791e-02],
#         [ 5.23026705e-01,  5.88966429e-01,  1.34341598e-01,
#          -2.56171942e-01]],
#
#        [[ 4.12837416e-01,  3.15916985e-01,  8.10266808e-02,
#          -4.23455536e-01],
#         [ 7.03615665e-01,  2.20379636e-01, -1.44984797e-02,
#          -4.49137270e-01],
#         [ 5.21189153e-01,  3.66969407e-01,  3.53052408e-01,
#          -6.20253325e-01],
#         [ 5.11480033e-01,  4.43908066e-01,  5.79632759e-01,
#          -6.89541042e-01],
#         [ 5.02104461e-01,  4.63609934e-01,  6.43488228e-01,
#          -7.99010098e-01],
#         [ 6.29566729e-01,  4.37716544e-01,  9.66300011e-01,
#          -8.36284816e-01],
#         [ 5.34786642e-01,  3.33897233e-01,  1.14843166e+00,
#          -7.27509439e-01],
#         [ 2.57414371e-01,  3.56368303e-01,  1.09924340e+00,
#          -7.81730890e-01],
#         [ 3.83292258e-01,  4.03112561e-01,  7.86636233e-01,
#          -7.12899804e-01],
#         [ 5.45370519e-01,  3.70022357e-01,  6.52568102e-01,
#          -6.25372291e-01],
#         [ 4.94722277e-01,  2.78717667e-01,  3.49892408e-01,
#          -5.03583968e-01],
#         [ 3.43542695e-01,  2.16749638e-01,  1.65438727e-02,
#          -4.49037015e-01],
#         [ 4.86294031e-01,  3.77888650e-01,  2.89979458e-01,
#          -4.73544478e-01]]], dtype=float32)

# %%
y_pred[1][0].shape, anchors[1]
# Out:
# ((26, 26, 255), [30, 61, 62, 45, 59, 119])

# %%
y_pred[2][0].shape, anchors[2]
# Out:
# ((52, 52, 255), [10, 13, 16, 30, 33, 23])

# %%
#x, y, w, h = netout[int(row)][int(col)][b][:4]
x, y, w, h = y_pred[0][0][0][0][:4]
x, y, w, h
# Out:
# (0.42410854, 0.57156533, 0.46833396, -0.47841114)

# %%
y_pred[1][0][0][0][:4]
# Out:
# array([ 0.43996766,  0.5709363 , -0.48455268,  0.26779768], dtype=float32)
